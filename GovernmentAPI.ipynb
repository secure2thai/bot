# %% [markdown]
# <a href="https://colab.research.google.com/github/secure2thai/bot/blob/master/GovernmentAPI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""GovernmentAPI.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1CzqYLjLfddbSZhYBVDfrRIDY5wwTMYkM
"""

import requests
from pprint import pprint
import matplotlib.pyplot as plt


def SearchProject(keyword_search='เรือดำน้ำ',year=2561,limit=200):

  url = 'https://opend.data.go.th/govspending/cgdcontract'
  #url = 'https://opend.data.go.th/govspending/summary_cgdcontract'

  token = 'rcdV5Vub9doETaWI798M0sNUCScd0q0O'

  parameters = {'api-key':token, 
                'year':year,
                'keyword':keyword_search,
                'limit':limit
                }

  r = requests.get(url,params=parameters)
  result = r.json()
  print(result)

  allproject = result['result']
  #print(type(allproject))
  print('Count: ',len(allproject)) # len() คือการนับค่าใน List / Dict
  #pprint(allproject[8])

  allbudget = []
  projectname = []

  print('----parameter-----')
  print(allproject[0].keys())
  print('------------------')

  for pj in allproject:
    print(pj['dept_name'])
    print(pj['sum_price_agree'])
    print(pj['project_name'])
    print(pj['transaction_date'])
    allbudget.append(int(pj['sum_price_agree'].replace(',','')))
    projectname.append(pj['project_name'])
    print('---------------')
  print('***************************************************')
  print('ค้นหาคำว่า: {} งบประมาณทั้งหมด: {:,d} บาท'.format(keyword_search,sum(allbudget)))
  print('***************************************************')

  # graph
  # xbar = range(len(projectname))
  # plt.bar(xbar,allbudget)
  # plt.xticks(projectname)
  # plt.show()


SearchProject('หน้ากากอนามัย')
# Out:
# {'code': '200', 'status': 'success', 'msg': '', 'time': '2020-03-15 11:46:55', 'param_obj': {'year': 2561, 'keyword': 'หน้ากากอนามัย', 'dept_name': '', 'winner_tin': '', 'winner': '', 'budget_start': 0, 'budget_end': '', 'offset': 0, 'limit': 200}, 'result': [{'project_id': '61067403148', 'project_name': 'ซื้อหน้ากากอนามัย-ถุงมือหนังฟอร์นิเจอร์ จำนวน ๒๐ รายการ โครงการฝายกั้นลำน้ำลำพะยัง(บ้านมะนาว) ตำบลเหล่าใหญ่ อำเภอกุฉินารายณ์ จังหวัดกาฬสินธุ์ โดยวิธีเฉพาะเจาะจง', 'project_type_name': 'ซื้อ', 'dept_name': 'กรมชลประทาน', 'dept_sub_name': 'โครงการก่อสร้าง สำนักชลประทานที่ 6 ขอนแก่น', 'purchase_method_group_name': 'เฉพาะเจาะจง', 'announce_date': '-', 'project_money': '498,560', 'price_build': '498,560', 'sum_price_agree': '498,560', 'budget_year': '2561', 'transaction_date': '26 มิ.ย. 61', 'province': 'ขอนแก่น', 'district': 'เมืองขอนแก่น', 'subdistrict': 'ในเมือง', 'project_status': 'สิ้นสุดสัญญา', 'geom': '', 'contract': [{'winner_tin': '0443536000246', 'winner': 'ฟอเรสท์  เอ็นจิเนียริ่ง', 'contract_no': '517/2561', 'contract_date': '26 มิ.ย. 61', 'contract_finish_date': '3 ก.ค. 61', 'price_agree': '498,560', 'status': 'สิ้นสุดสัญญา'}]}, {'project_id': '61067524139', 'project_name': 'ซื้อหน้ากากอนามัย-เหล็กสกัดปลายแหลม จำนวน ๒๓ รายการ โครงการฝายห้วยเตรียม ตำบลกุดสิมคุ้มใหม่ อำเภอเขาวง จังหวัดกาฬสินธุ์ โดยวิธีเฉพาะเจาะจง', 'project_type_name': 'ซื้อ', 'dept_name': 'กรมชลประทาน', 'dept_sub_name': 'โครงการก่อสร้าง สำนักชลประทานที่ 6 ขอนแก่น', 'purchase_method_group_name': 'เฉพาะเจาะจง', 'announce_date': '-', 'project_money': '495,200', 'price_build': '495,200', 'sum_price_agree': '495,200', 'budget_year': '2561', 'transaction_date': '2 ก.ค. 61', 'province': 'ขอนแก่น', 'district': 'เมืองขอนแก่น', 'subdistrict': 'ในเมือง', 'project_status': 'สิ้นสุดสัญญา', 'geom': '', 'contract': [{'winner_tin': '1461300120392', 'winner': 'ณัฐพงศ์การค้า', 'contract_no': '549/2561', 'contract_date': '2 ก.ค. 61', 'contract_finish_date': '10 ก.ค. 61', 'price_agree': '495,200', 'status': 'สิ้นสุดสัญญา'}]}, {'project_id': '60117213431', 'project_name': 'ซื้อน้ำยาพ่นหมอกควัน, ทรายกำจัดลูกน้ำยุงลาย และหน้ากากอนามัยสำหรับพ่นหมอกควันชนิดผ้าคาร์บอน จำนวน 3 รายการ เพื่อใช้ในโครงการป้องกันและควบคุมโรคไข้เลือดออก เทศบาลตำบลเขตรอุดมศักดิ์ ประจำปีงบประมาณ พ.ศ.2561 โดยวิธีเฉพาะเจาะจง', 'project_type_name': 'ซื้อ', 'dept_name': 'เทศบาลตำบลเขตรอุดมศักดิ์', 'dept_sub_name': 'เทศบาลตำบลเขตรอุดมศักดิ์', 'purchase_method_group_name': 'เฉพาะเจาะจง', 'announce_date': '-', 'project_money': '392,000', 'price_build': '336,194', 'sum_price_agree': '355,026', 'budget_year': '2561', 'transaction_date': '15 พ.ย. 60', 'province': 'ชลบุรี', 'district': 'สัตหีบ', 'subdistrict': 'สัตหีบ', 'project_status': 'ระหว่างดำเนินการ', 'geom': '', 'contract': [{'winner_tin': '0203535000082', 'winner': 'นายสุวัฒน์  เลิศประเสริฐเวช', 'contract_no': '3/2561', 'contract_date': '15 พ.ย. 60', 'contract_finish_date': '19 พ.ย. 60', 'price_agree': '355,026', 'status': 'ระหว่างดำเนินการ'}]}, {'project_id': '61017314243', 'project_name': 'ซื้อหน้ากากอนามัย จำนวน ๓,๐๐๐ กล่อง โดยวิธีเฉพาะเจาะจง', 'project_type_name': 'ซื้อ', 'dept_name': 'กรุงเทพมหานคร', 'dept_sub_name': 'กองทันตสาธารณสุข สำนักอนามัย กรุงเทพมหานคร', 'purchase_method_group_name': 'เฉพาะเจาะจง', 'announce_date': '-', 'project_money': '129,000', 'price_build': '129,000', 'sum_price_agree': '129,000', 'budget_year': '2561', 'transaction_date': '22 ม.ค. 61', 'province': 'กรุงเทพมหานคร', 'district': 'ดินแดง', 'subdistrict': 'ดินแดง', 'project_status': 'ระหว่างดำเนินการ', 'geom': '', 'contract': [{'winner_tin': '0125541000270', 'winner': 'บริษัท โทรฟี จำกัด', 'contract_no': '11-36-61', 'contract_date': '22 ม.ค. 61', 'contract_finish_date': '27 ม.ค. 61', 'price_agree': '129,000', 'status': 'ระหว่างดำเนินการ'}]}, {'project_id': '61067111187', 'project_name': 'ซื้อยาฆ่าหญ้าชนิดดูดซึม-หน้ากากอนามัย จำนวน ๒ รายการ ของงาน ซ่อมแซมบำรุงรักษาระบบชลประทาน โครงการส่งน้ำและบำรุงรักษาแม่ลาว ตำบลดงมะดะ อำเภอแม่ลาว จังหวัดเชียงราย โดยวิธีเฉพาะเจาะจง', 'project_ ...
# Count:  123
# ----parameter-----
# dict_keys(['project_id', 'project_name', 'project_type_name', 'dept_name', 'dept_sub_name', 'purchase_method_group_name', 'announce_date', 'project_money', 'price_build', 'sum_price_agree', 'budget_year', 'transaction_date', 'province', 'district', 'subdistrict', 'project_status', 'geom', 'contract'])
# ------------------
# กรมชลประทาน
# 498,560
# ซื้อหน้ากากอนามัย-ถุงมือหนังฟอร์นิเจอร์ จำนวน ๒๐ รายการ โครงการฝายกั้นลำน้ำลำพะยัง(บ้านมะนาว) ตำบลเหล่าใหญ่ อำเภอกุฉินารายณ์ จังหวัดกาฬสินธุ์ โดยวิธีเฉพาะเจาะจง
# 26 มิ.ย. 61
# ---------------
# กรมชลประทาน
# 495,200
# ซื้อหน้ากากอนามัย-เหล็กสกัดปลายแหลม จำนวน ๒๓ รายการ โครงการฝายห้วยเตรียม ตำบลกุดสิมคุ้มใหม่ อำเภอเขาวง จังหวัดกาฬสินธุ์ โดยวิธีเฉพาะเจาะจง
# 2 ก.ค. 61
# ---------------
# เทศบาลตำบลเขตรอุดมศักดิ์
# 355,026
# ซื้อน้ำยาพ่นหมอกควัน, ทรายกำจัดลูกน้ำยุงลาย และหน้ากากอนามัยสำหรับพ่นหมอกควันชนิดผ้าคาร์บอน จำนวน 3 รายการ เพื่อใช้ในโครงการป้องกันและควบคุมโรคไข้เลือดออก เทศบาลตำบลเขตรอุดมศักดิ์ ประจำปีงบประมาณ พ.ศ.2561 โดยวิธีเฉพาะเจาะจง
# 15 พ.ย. 60
# ---------------
# กรุงเทพมหานคร
# 129,000
# ซื้อหน้ากากอนามัย จำนวน ๓,๐๐๐ กล่อง โดยวิธีเฉพาะเจาะจง
# 22 ม.ค. 61
# ---------------
# กรมชลประทาน
# 108,380
# ซื้อยาฆ่าหญ้าชนิดดูดซึม-หน้ากากอนามัย จำนวน ๒ รายการ ของงาน ซ่อมแซมบำรุงรักษาระบบชลประทาน โครงการส่งน้ำและบำรุงรักษาแม่ลาว ตำบลดงมะดะ อำเภอแม่ลาว จังหวัดเชียงราย โดยวิธีเฉพาะเจาะจง
# 11 มิ.ย. 61
# ---------------
# เทศบาลเมืองชุมแพ
# 99,995
# ซื้อถุงมือปราศจากเชื้อ,หน้ากากอนามัย,แอลกอฮอล์เจลฆ่าเชื้อ,น้ำยาทำความสะอาดฆ่าเชื้อ โครงการควบคุมป้องกันโรคมือ เท้า ปาก โดยวิธีเฉพาะเจาะจง
# 12 มิ.ย. 61
# ---------------
# กรมชลประทาน
# 99,966
# ซื้อหน้ากากอนามัยกรองฝุ่นละออง และอื่นๆ จำนวน 25 รายการ โดยวิธีเฉพาะเจาะจง
# 7 พ.ค. 61
# ---------------
# สถาบันราชประชาสมาสัย
# 98,975
# ซื้อหน้ากากอนามัย 3 ชั้น โดยวิธีเฉพาะเจาะจง
# 18 พ.ค. 61
# ---------------
# โรงพยาบาลราชวิถี
# 85,600
# ซื้อหน้ากากอนามัยคาร์บอน 4 ชั้นคล้องหู (Face Mask Carbon 4 Ply) 50 ชิ้น/กล่อง จำนวน 200 กล่อง โดยวิธีเฉพาะเจาะจง
# 6 มิ.ย. 61
# ---------------
# โรงพยาบาลราชวิถี
# 80,000
# ซื้อหน้ากากอนามัยคาร์บอน 4 ชั้นคล้องหู  จำนวน 200 กล่อง โดยวิธีเฉพาะเจาะจง
# 1 พ.ย. 60
# ---------------
# องค์การบริหารส่วนตำบลวังใหม่
# 78,220
# ซื้อจัดซื้อวัคซีนป้องกันโรคพิษสุนัขบ้า จำนวน 2,715 โต๊ส พร้อมอุปกรณ์ในการฉีด เข็ม ไซริงค์ เหรียญห้อยค  และใบรับรองการฉีดวัคซีน  ถุงมือยาง  และหน้ากากอนามัย ตามโครงการรณรงค์ป้องกันโรคพิษสุนัขบ้าและควบคุมการขยายพันธุ์สัตว์ ปีงบประมาณ 2561 โดยวิธีเฉพาะเจาะจง
# 8 พ.ค. 61
# ---------------
# กรมชลประทาน
# 73,050
# ซื้อยาปรับสภาพน้ำ - หน้ากากอนามัย รวม 12 รายการ พด.572/61 ศศพ. โดยวิธีเฉพาะเจาะจง
# 17 ส.ค. 61
# ---------------
# กรมคุมประพฤติ
# 65,800
# ซื้อชุดตรวจปัสสาวะ (ยาบ้า,กัญชา) หน้ากากอนามัยคาร์บอน โดยวิธีเฉพาะเจาะจง
# 29 มี.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลนาขมิ้น
# 65,000
# ซื้อทรายอะเบท พร้อมหน้ากากอนามัยและถุงมือยางพารา โดยวิธีเฉพาะเจาะจง
# 11 มิ.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลไพรบึง
# 58,900
# ซื้อค่าวัสดุวิทยาศาสตร์และการแพทย์ค่าวัคซีน,ค่ากระบอกฉีดยา,เข็มฉีดยา,ถุงมือยาง,หน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 4 ต.ค. 60
# ---------------
# สถาบันบำราศนราดูร
# 57,000
# ซื้อหน้ากากอนามัยชนิดคล้องหู สำหรับเด็ก โดยวิธีเฉพาะเจาะจง
# 28 พ.ย. 60
# ---------------
# องค์การบริหารส่วนตำบลบ้านคา
# 51,150
# ซื้อวัคซีนป้องกันโรคพิษสุนัขบ้าพร้อมอุปกรณ์ จำนวน 3 รายการ 1.วัคซีนพร้อมอุปกรณ์ จำนวน 1,600 ชุด 2.ถุงมือสำหรับการตรวจวินิจฉัยทางการแพทย์ size m, s จำนวน 10 กล่อง 3.หน้ากากอนามัย 3 ชั้น แบบคล้องหู จำนวน 10 กล่อง โดยวิธีเฉพาะเจาะจง
# 29 มิ.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลหนองคอนไทย
# 50,840
# ซื้อจัดซื้อวัคซีนป้องกันโรคพิษสุนัขบ้า (เครื่องหมายประจำตัวสัตว์ และใบรับรองการฉีดวัคซีน)  จัดซื้อเข็ม , ไซริงค์ , ถุงมือแพทย์ชนิดใช้แล้วทิ้ง   และจัดซื้อหน้ากากอนามัย    เพื่อใช้ในการป้องกันควบคุมโรคพิษสุนัขบ้า   ภายในเขตองค์การบริหารส่วนตำบลหนองคอนไทย โดยวิธีเฉพาะเจาะจง
# 18 ก.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลโพรงอากาศ
# 45,600
# ซื้อสารเคมีกำจัดยุงและแมลง จำนวน 35  ลิตร และหน้ากากอนามัยอย่างดี  จำนวน  3  กล่อง ตามโครงการรณรงค์โรคติดต่อที่มียุงเป็นพาหะ โดยวิธีเฉพาะเจาะจง
# 21 มิ.ย. 61
# ---------------
# กรมราชทัณฑ์
# 45,000
# ซื้ออุปกรณ์ในการจู่โจมตรวจค้น,ชุดทดสอบหาสารเสพติด หน้ากากอนามัยและถุงมือ โดยวิธีเฉพาะเจาะจง
# 16 ส.ค. 61
# ---------------
# กรมราชทัณฑ์
# 45,000
# ซื้ออุปกรณ์ใช้ในการจู่โจมตรวจค้นเรือนจำ (ชุดทดสอบสารเสพติด หน้ากากอนามัยและถุงมือ) โดยวิธีเฉพาะเจาะจง
# 16 ก.ค. 61
# ---------------
# โรงพยาบาลเทพรัตน์นครราชสีมา
# 44,000
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 17 พ.ค. 61
# ---------------
# สำนักงานสาธารณสุขจังหวัดปัตตานี
# 42,500
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 23 พ.ค. 61
# ---------------
# สำนักงานสาธารณสุขจังหวัดชลบุรี
# 42,490
# ซื้อหน้ากากอนามัย จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 17 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลโคกใหญ่
# 41,960
# ซื้อวัคซีนป้องกันพิษสุนัขบ้า ขนาด 1 ซีซี จำนวน 1,400 ขวด,ไซริงค์ ขนาด 3 ซีซี จำนวน 1,480 อัน,เข็มฉีดยา จำนวน 1,480 เล่ม,หน้ากากอนามัยปิดจมูก จำนวน 2 กล่อง โดยวิธีเฉพาะเจาะจง
# 19 มิ.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลเพ็ญ
# 40,000
# ซื้อหน้ากากอนามัย เพื่อเตรียมความพร้อมการป้องกันโรคไข้หวัดใหญ่ในเขตพื้นที่องค์การบริหารส่วนตำบลเพ็ญ ประจำปีงบประมาณ 2561 โดยวิธีเฉพาะเจาะจง
# 4 ธ.ค. 60
# ---------------
# โรงพยาบาลท่าตูม
# 36,000
# ซื้อหน้ากากอนามัย Mask  Disposable โดยวิธีเฉพาะเจาะจง
# 1 ก.พ. 61
# ---------------
# โรงพยาบาลครบุรี
# 35,838
# ซื้อถุงมือ หน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 14 พ.ย. 60
# ---------------
# โรงพยาบาลภูเวียง
# 35,310
# ซื้อหน้ากากอนามัย รุ่น N.95  1 รายการ โดยวิธีเฉพาะเจาะจง
# 21 ส.ค. 61
# ---------------
# กรมราชทัณฑ์
# 34,990
# ซื้ออุปกรณ์ในการจู่โจมตรวจค้น,ชุดทดสอบหาสารเสพติด,หน้ากากอนามัยและถุงมือ โดยวิธีเฉพาะเจาะจง
# 31 ก.ค. 61
# ---------------
# กรมราชทัณฑ์
# 34,990
# ซื้ออุปกรณ์ในการจู่โจมตรวจค้น ชุดทดสอบหาสารเสพติด,หน้ากากอนามัยและถุงมือ โดยวิธีเฉพาะเจาะจง
# 19 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลบุ่ง
# 34,950
# ซื้อทรายอะเบต  จำนวน  5  ถังน้ำยาพ่นหมอกควัน  15 ลิตร  หน้ากากอนามัย  3 d]jv โดยวิธีเฉพาะเจาะจง
# 15 พ.ค. 61
# ---------------
# โรงพยาบาลท่าศาลา
# 32,200
# ซื้อMASK DISPOSIBLE หน้ากากอนามัยชนิดใช้ครั้งเดียว จำนวน ๑ รายการ โดยวิธีเฉพาะเจาะจง
# 13 พ.ย. 60
# ---------------
# กรมราชทัณฑ์
# 30,660
# ซื้อวัสดุหน้ากากอนามัยและถุงมือยางโครงการเรือนจำปลอดยาเสพติด โดยวิธีเฉพาะเจาะจง
# 12 ม.ค. 61
# ---------------
# สำนักงานปลัดกระทรวงสาธารณสุข
# 29,998
# ซื้อหน้ากากอนามัย  จำนวน  845  กล่อง โดยวิธีเฉพาะเจาะจง
# 11 ม.ค. 61
# ---------------
# กรมราชทัณฑ์
# 29,985
# ซื้อวัสดุถุงมือและหน้ากากอนามัยโครงการเรือนจำปลอดยาเสพติด โดยวิธีเฉพาะเจาะจง
# 27 พ.ย. 60
# ---------------
# เทศบาลตำบลนาดี
# 28,000
# ซื้อจัดซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ (หน้ากากอนามัยแบบใช้แล้วทิ้ง(แบบ ๓ชั้น ) โดยวิธีเฉพาะเจาะจง
# 9 ก.พ. 61
# ---------------
# สำนักงานปลัดกระทรวงสาธารณสุข
# 25,200
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 13 ก.พ. 61
# ---------------
# โรงพยาบาลอุทัยธานี
# 25,130
# ซื้อหน้ากากอนามัยชนิดใช้ครั้งเดียวแบบคล้องหู 50ชิ้น/กล่อง โดยวิธีเฉพาะเจาะจง
# 5 มิ.ย. 61
# ---------------
# โรงพยาบาลนาดี
# 24,400
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 1 พ.ย. 60
# ---------------
# สำนักงานคณะกรรมการป้องกันและปราบปรามยาเสพติด
# 23,781
# ซื้อกระปุกพลาสติกเก็บปัสสาวะ  หน้ากากอนามัย  ถุงมือสำหรับตรวจโรค  เจลทำความสะอาดมือ  และถุงซิป โดยวิธีเฉพาะเจาะจง
# 11 ม.ค. 61
# ---------------
# โรงพยาบาลภูเวียง
# 23,540
# ซื้อหน้ากากอนามัย 1 รายการ โดยวิธีเฉพาะเจาะจง
# 16 มี.ค. 61
# ---------------
# โรงพยาบาลม่วงสามสิบ
# 22,604
# ซื้อหน้ากากอนามัยและสำลีก้อน โดยวิธีเฉพาะเจาะจง
# 21 ธ.ค. 60
# ---------------
# โรงพยาบาลเกาะสมุย
# 22,200
# ซื้อหน้ากากอนามัย Mask dispose โดยวิธีเฉพาะเจาะจง
# 10 ก.ย. 61
# ---------------
# โรงพยาบาลครบุรี
# 22,200
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 19 ธ.ค. 60
# ---------------
# กรมวิทยาศาสตร์การแพทย์
# 21,796
# ซื้อ1.	Pipet Tip 1000 ul.2.	Volumetric Pipette 25 ml.3.	ถุงมือยางดีสพอสเซเบิ้ล เบอร์ XS4.	ถุงมือยางดีสพอสเซเบิ้ล เบอร์ S5.	ถุงมือยางดีสพอสเซเบิ้ล เบอร์ M6.	หน้ากากอนามัยปิดจมูก  ชนิดเกี่ยว โดยวิธีเฉพาะเจาะจง
# 30 พ.ย. 60
# ---------------
# โรงพยาบาลกันทรวิชัย
# 21,787
# ซื้อถุงมือดิสโพส,หน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 6 พ.ย. 60
# ---------------
# โรงพยาบาลสมเด็จพระยุพราชเลิงนกทา
# 20,000
# ซื้อวัสดุการแพทย์  จำนวน  1  รายการ (หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 6 ก.ย. 61
# ---------------
# โรงพยาบาลโกสุมพิสัย
# 20,000
# ซื้อหน้ากากอนามัย แบบมีสายคล้อง จำนวน ๕๐๐ กล่อง โดยวิธีเฉพาะเจาะจง
# 24 ส.ค. 61
# ---------------
# มหาวิทยาลัยธรรมศาสตร์ ศูนย์รังสิต
# 19,260
# ซื้อวัสดุเวชภัณฑ์ทางการแพทย์ศูนย์รังสิต หน้ากากอนามัย ชนิด ๓ ชั้น คล้องหู(ตามใบเสนอราคาแนบ)(๑๗) โดยวิธีเฉพาะเจาะจง
# 19 เม.ย. 61
# ---------------
# เทศบาลตำบลสตึก
# 19,200
# ซื้อวัสดุเครื่องแต่งกาย (หน้ากากอนามัย ผ้าสาลู) โดยวิธีเฉพาะเจาะจง
# 27 มิ.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลทุ่งคอก
# 18,825
# ซื้อค่าจัดซื้อน้ำยาฆ่าเชื้อโรคและหน้ากากอนามัยป้องกันเชื้อโรค โดยวิธีเฉพาะเจาะจง
# 16 ก.ค. 61
# ---------------
# โรงพยาบาลตะกั่วป่า
# 18,500
# ซื้อวัสดุการแพทย์ หน้ากากอนามัย 3 ชั้น มีสายคล้องหู จำนวน 500 กล่อง โดยวิธีเฉพาะเจาะจง
# 27 ส.ค. 61
# ---------------
# โรงพยาบาลตะกั่วป่า
# 18,500
# ซื้อวัสดุการแพทย์ หน้ากากอนามัย 3 ชั้น มีสายคล้องหู จำนวน 500 กล่อง โดยวิธีเฉพาะเจาะจง
# 10 เม.ย. 61
# ---------------
# โรงพยาบาลตะกั่วป่า
# 18,500
# ซื้อวัสดุการแพทย์ หน้ากากอนามัย 3 ชั้น มีสายคล้องหู จำนวน 500 กล่อง โดยวิธีเฉพาะเจาะจง
# 21 ก.พ. 61
# ---------------
# โรงพยาบาลตะกั่วป่า
# 18,500
# ซื้อหน้ากากอนามัย ที่ปิดจมูก ชนิดคล้องหู 50 ชิ้น  จำนวน 500 กล่อง โดยวิธีเฉพาะเจาะจง
# 13 พ.ย. 60
# ---------------
# โรงพยาบาลนครนายก
# 18,375
# ซื้อเวชภัณฑ์ 1 รายการ (Face Mask (หน้ากากอนามัย3ชั้น)) โดยวิธีเฉพาะเจาะจง
# 4 ก.ย. 61
# ---------------
# โรงพยาบาลพานทอง
# 18,000
# ซื้อเวชภัณฑ์มิใช่ยา ประเภท หน้ากากอนามัย แบบคล้องหู โดยวิธีเฉพาะเจาะจง
# 18 เม.ย. 61
# ---------------
# เทศบาลตำบลเทพราช
# 17,200
# ซื้อเจลล้างมือ น้ำยาฆ่าเชื้อ หน้ากากอนามัย ใช้ในโครงการป้องกันและป้องกันควบคุมโรคติดต่อตามฤดูกาล โดยวิธีเฉพาะเจาะจง
# 16 ก.ค. 61
# ---------------
# สำนักงานสาธารณสุขจังหวัดสงขลา
# 17,000
# ซื้อหน้ากากอนามัยผ้าปิดปากปิดจมูกแบบคล้องศรีษะจำนวน 3 ชิ้นต่อซอง โดยวิธีเฉพาะเจาะจง
# 31 พ.ค. 61
# ---------------
# เทศบาลตำบลกุดสิมคุ้มใหม่
# 17,000
# ซื้อวัสดุเครื่องแต่งกาย (หน้ากากอนามัย รองเท้าบูท) โดยวิธีเฉพาะเจาะจง
# 12 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลจันทร์เพ็ญ
# 15,750
# ซื้อจัดซื้อวัสดุหน้ากากอนามัย , ถุงมือยางทำความสะอาดทั่วไป จำนวน 2 รายการ โดยวิธีเฉพาะเจาะจง
# 30 ส.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลทุ่งไทรทอง
# 15,280
# ซื้อจัดซื้อวัคซีนพร้อมชุดอุปกรณ์ในการฉีดวัคซีน  และหน้ากากอนามัย  ตามโครงการป้องกันและควบคุมโรคพิษสุนัขบ้า (สำนักปลัด อบต.) โดยวิธีเฉพาะเจาะจง
# 7 มิ.ย. 61
# ---------------
# โรงพยาบาลพุทไธสง
# 15,200
# ซื้อพัสดุทางการแพทย์ หน้ากากอนามัย Face Masks แบบคล้องหู  (กลุ่มการ) โดยวิธีเฉพาะเจาะจง
# 19 ต.ค. 60
# ---------------
# กองทัพอากาศ
# 14,400
# ซื้อหน้ากากอนามัย จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 6 ก.พ. 61
# ---------------
# โรงพยาบาลอุทัยธานี
# 14,360
# ซื้อหน้ากากอนามัยชนิดใช้ครั้งเดียวแบบคล้องหู บรรจุ 50 ชิ้น 400 กล่อง โดยวิธีเฉพาะเจาะจง
# 17 ส.ค. 61
# ---------------
# เทศบาลตำบลบ้านซ่อง
# 14,300
# ซื้อหน้ากากอนามัยและวัสดุชุดทดสอบสารปนเปื้อนในอาหาร รวมจำนวน 6 รายการ เพื่อใช้ในโครงการคุ้มครองผู้บริโภคในเขตเทศบาลตำบลบ้านซ่อง โดยวิธีเฉพาะเจาะจง
# 21 มิ.ย. 61
# ---------------
# โรงพยาบาลไทรน้อย
# 13,380
# ซื้อถุงมือตรวจโรคและหน้ากากอนามัยในโครงการบำบัดรักษาและฟื้นฟูสมรรถภาพผู้เสพ/ผู้ติดยาแบบ Matrix Program โดยวิธีเฉพาะเจาะจง
# 3 เม.ย. 61
# ---------------
# สำนักงานปลัดกระทรวงการต่างประเทศ
# 12,840
# ซื้อหน้ากากอนามัย จำนวน ๒,๐๐๐ ชิ้น โดยวิธีเฉพาะเจาะจง
# 23 ส.ค. 61
# ---------------
# โรงพยาบาลพังโคน
# 12,198
# ซื้อเวชภัณฑ์ที่ไม่ใช่ยา รายการ หน้ากากอนามัย จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 7 ธ.ค. 60
# ---------------
# โรงพยาบาลท่าเรือ
# 11,770
# ซื้อหน้ากากอนามัยชนิด N๙๕  ๑๐  กล่อง ๑ รายการ โดยวิธีเฉพาะเจาะจง
# 17 ก.ค. 61
# ---------------
# โรงพยาบาลคำม่วง
# 11,550
# ซื้อหน้ากากอนามัยแบบคล้องหู จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 8 ม.ค. 61
# ---------------
# โรงพยาบาลตะกั่วป่า
# 10,700
# ซื้อวัสดุการแพทย์ หน้ากากอนามัยชนิด N95 จำนวน 10 กล่อง โดยวิธีเฉพาะเจาะจง
# 1 มิ.ย. 61
# ---------------
# โรงพยาบาลค่ายสุรศักดิ์มนตรี
# 10,700
# ซื้อหน้ากากอนามัย 3 ชั้น ชนิดขึ้นรูป สำหรับป้องกันการซึมผ่านของของเหลว โดยวิธีเฉพาะเจาะจง
# 23 ก.พ. 61
# ---------------
# โรงพยาบาลบางแก้ว
# 10,520
# ซื้อจัดซื้อวัสดุการแพทย์ (เข็มฉีดยาหน้ากากอนามัย)  จำนวน 6  รายการ โดยวิธีเฉพาะเจาะจง
# 12 ต.ค. 60
# ---------------
# องค์การบริหารส่วนตำบลนราภิรมย์
# 10,340
# ซื้อหน้ากากป้องกันฝุ่นละอองและกลิ่น จำนวน 2 กล่อง , หน้ากากอนามัย(ผ้าใยสังเคราะห์) จำนวน 2 กล่อง , หน้ากากป้องกันสารเคมีชนิดไส้กรองพร้อมอุปกรณ์ครบชุด จำนวน 2 กล่อง , ถุงมือแพทย์(ชนิดมีแป้ง) จำนวน 2 กล่อง , แว่นครอบตานิรภัย จำนวน 2 กล่อง โดยวิธีเฉพาะเจาะจง
# 1 ธ.ค. 60
# ---------------
# เทศบาลตำบลสะเตงนอก
# 9,900
# ซื้อหน้ากากอนามัย กองสาธารณสุข โดยวิธีเฉพาะเจาะจง
# 4 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลบางตะไนย์
# 9,750
# ซื้อวัสดุงานบ้านงานครัว (ถุงมือยาง,หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 7 ส.ค. 61
# ---------------
# โรงพยาบาลบางขัน
# 9,500
# ซื้อวัสดุการแพทย์ (หน้ากากอนามัย)  จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 21 มี.ค. 61
# ---------------
# โรงพยาบาลเชียงรายประชานุเคราะห์
# 9,400
# ซื้อเวชภัณฑ์ที่มิใช่ยา ประเภทวัสดุการแพทย์ เสื้อกาว์น ไม่มีหน้ากากอนามัยและหมวก (CPE ISOLATION GOWN) จำนวน ๒๐๐ ชุด โดยวิธีเฉพาะเจาะจง
# 20 มิ.ย. 61
# ---------------
# กรมธนารักษ์
# 9,240
# ซื้อวัสดุการแพทย์ (ถุงมือยางและหน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 7 ส.ค. 61
# ---------------
# กรมปศุสัตว์
# 9,040
# ซื้อวัสดุวิทยาศาสตร์และการแพทย์ (ก๊อชพับ, ถุงมือตรวจโรค, หน้ากากอนามัย, ไซริ้งพลาสติก) โดยวิธีเฉพาะเจาะจง
# 19 เม.ย. 61
# ---------------
# โรงพยาบาลฮอด
# 9,000
# ซื้อเวชภัณฑ์ที่มิใช่ยา จำนวน 1 รายการ (หน้ากากอนามัย 3 ชั้น สีเขียว) โดยวิธีเฉพาะเจาะจง
# 24 ส.ค. 61
# ---------------
# โรงพยาบาลฮอด
# 9,000
# ซื้อเวชภัณฑ์ที่มิใช่ยา จำนวน 1 รายการ (หน้ากากอนามัย 3 ชั้น สีเขียว) โดยวิธีเฉพาะเจาะจง
# 10 ม.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลละแม
# 8,810
# ซื้อวัสดุเครื่องแต่งกาย จำนวน ๔ รายการ ได้แก่ ถุงมือยาง ถุงมือผ้า เสื้อกันฝน และหน้ากากอนามัย (สำนักปลัด) โดยวิธีเฉพาะเจาะจง
# 24 ส.ค. 61
# ---------------
# โรงพยาบาลโซ่พิสัย
# 8,800
# ซื้อหน้ากากอนามัย (100 ชิ้น/กล่อง)  จำนวน 100 กล่อง) โดยวิธีเฉพาะเจาะจง
# 8 ก.พ. 61
# ---------------
# องค์การบริหารส่วนตำบลบาเระเหนือ
# 8,550
# ซื้อเสื้อแขนยาวพร้อมแถบสะท้อนแสงและหน้ากากอนามัย  โครงการฝึกอบรม  การป้องกันหมอกควันและไฟป่า  ประจำปี  2561 โดยวิธีเฉพาะเจาะจง
# 28 ส.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลบ้านใหม่
# 8,290
# ซื้อวัคซีนป้องกันโรคพิษสุนัขพร้อมอุปกรณ์ฉีด จำนวน 300 โด๊ส และหน้ากากอนามัย จำนวน 5 กล่อง,ถุงมือ(แบบใช้แล้วทิ้ง จำนวน 3 กล่อง ใช้ในแผนงานสาธารณสุขอบต.บ้านใหม่ โดยวิธีเฉพาะเจาะจง
# 24 ก.ค. 61
# ---------------
# โรงพยาบาลโซ่พิสัย
# 8,132
# ซื้อหน้ากากอนามัย  (50 ชิ้น/กล่อง) โดยวิธีเฉพาะเจาะจง
# 2 พ.ค. 61
# ---------------
# กรมราชทัณฑ์
# 8,100
# ซื้อถุงมือยางและหน้ากากอนามัย จำนวน 2 รายการ โดยวิธีเฉพาะเจาะจง
# 2 พ.ย. 60
# ---------------
# องค์การบริหารส่วนตำบลมหาสวัสดิ์
# 7,920
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์  จำนวน  ๑  รายการ  ดังนี้-หน้ากากอนามัย จำนวน  ๓  โหล  เป็นเงิน  ๗,๙๒๐.-  บาท (เจ็ดพันเก้าร้อยยี่สืบบาทถ้วน) โดยวิธีเฉพาะเจาะจง
# 15 ม.ค. 61
# ---------------
# โรงพยาบาลพิบูลมังสาหาร
# 7,700
# ซื้อวัสดุ เข็มเย็บแผล,หน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 16 พ.ย. 60
# ---------------
# โรงพยาบาลบ้านสร้าง
# 7,700
# ซื้อผ้าพันแผล  และหน้ากากอนามัยแบบคล้องหู โดยวิธีเฉพาะเจาะจง
# 5 เม.ย. 61
# ---------------
# เทศบาลตำบลลานหอย
# 7,600
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ ประเภทถุงมือยาง และหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 2 มี.ค. 61
# ---------------
# โรงพยาบาลวังวิเศษ
# 7,600
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 6 พ.ย. 60
# ---------------
# โรงพยาบาลคีรีรัฐนิคม
# 7,400
# disposable face mask(หน้ากากอนามัยสำหรับใช้ครั้งเดียว)
# 25 ต.ค. 60
# ---------------
# กรมราชทัณฑ์
# 7,050
# ซื้อถุงมือยางและหน้ากากอนามัย จำนวน 2 รายการ โดยวิธีเฉพาะเจาะจง
# 12 ก.พ. 61
# ---------------
# โรงพยาบาลบ้านกรวด
# 7,000
# ซื้อหน้ากากอนามัย 50 ชิ้น/กล่อง จำนวน 200 กล่อง โดยวิธีเฉพาะเจาะจง
# 14 มิ.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลพิชัย
# 7,000
# ซื้ออุปกรณ์ตามโครงการเฝ้าระวัง 100 วันอันตรายจากการเกิดไฟป่าและหมอกควันประจำปี 2561 คือ หน้ากากอนามัย จำนวน 10 กล่อง และ ไม้กวาดทางมะพร้าว จำนวน 100 อัน โดยวิธีเฉพาะเจาะจง
# 25 ม.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลน้ำพุ
# 6,620
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ (น้ำยาพ่นหมอกควัน หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 30 ม.ค. 61
# ---------------
# กรมควบคุมโรค
# 6,600
# จ้างผลิตสื่อประชาสัมพันธ์(ซองใส่หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 21 ก.พ. 61
# ---------------
# โรงพยาบาลหนองคาย
# 6,384
# ซื้อวัสดุการแพทย์ รายการ หน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 24 ม.ค. 61
# ---------------
# โรงพยาบาลวังสมบูรณ์
# 6,232
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ (หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 9 เม.ย. 61
# ---------------
# โรงพยาบาลกุดบาก
# 6,099
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 17 ส.ค. 61
# ---------------
# โรงพยาบาลพังโคน
# 6,099
# ซื้อวัสดุทางการแพทย์ หน้ากากอนามัย จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 28 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลบ้านไผ่
# 6,090
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์(ทรายกำจัดลูกน้ำยุงลาย หน้ากากอนามัย ถุงมือยางอนามัย โดยวิธีเฉพาะเจาะจง
# 15 มิ.ย. 61
# ---------------
# เทศบาลตำบลคูขวาง
# 6,000
# ซื้อวัสดุแต่งกายพนักงานประจำรถขยะ (หน้ากากอนามัย) โดยวิธีเฉพาะเจาะจง
# 4 ม.ค. 61
# ---------------
# โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านตลาดบึง
# 6,000
# ซื้อหน้ากากอนามัย โดยวิธีเฉพาะเจาะจง
# 19 มิ.ย. 61
# ---------------
# โรงพยาบาลละงู
# 5,700
# ซื้อหน้ากากอนามัยแบบคล้อง Face mask earloop โดยวิธีเฉพาะเจาะจง
# 1 พ.ย. 60
# ---------------
# โรงพยาบาลบางขัน
# 5,700
# ซื้อวัสดุการแพทย์ (หน้ากากอนามัย)  จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 23 ม.ค. 61
# ---------------
# โรงพยาบาลพระนั่งเกล้า
# 5,600
# ซื้อวัสดุทางการแพทย์ หน้ากากอนามัย ( Mask ) โดยวิธีเฉพาะเจาะจง
# 22 ส.ค. 61
# ---------------
# โรงพยาบาลบางบัวทอง
# 5,500
# ซื้อหน้ากากอนามัย N๙๕ จำนวน ๑ รายการ โดยวิธีเฉพาะเจาะจง
# 21 ส.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลแม่สลองใน
# 5,400
# ซื้อวัสดุอุปกรณ์สาธิตในการฝึกอบรม เช่น เข็มหยอดวัคซีน ชุดเข็มฉีดยา ถุงมือ หน้ากากอนามัย ตามโครงการฝึกอบรมให้ความรู้การเลี้ยง การสุขาภิบาลและการป้องกันโรคในสัตว์ปีก ประจำปีงบประมาณ 2561 โดยวิธีเฉพาะเจาะจง
# 24 พ.ย. 60
# ---------------
# โรงพยาบาลเบตง
# 5,100
# ซื้อหน้ากากอนามัย N95 จำนวน 6 กล่อง โดยวิธีเฉพาะเจาะจง
# 19 ม.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลมะรือโบออก
# 5,000
# ซื้อวัสดุอุปหรณ์สำหรับใช้ในโครงการ (ไม้กวาด, ถุงพลาสติก, ถุงมือ, หน้ากากอนามัย, และ ฯลฯ) โดยวิธีเฉพาะเจาะจง
# 8 ส.ค. 61
# ---------------
# โรงพยาบาลบางขัน
# 4,750
# ซื้อวัสดุการแพทย์  (หน้ากากอนามัย N95)  จำนวน 1 รายการ โดยวิธีเฉพาะเจาะจง
# 10 ก.ค. 61
# ---------------
# กรมชลประทาน
# 4,690
# ซื้อชุดตรวจสอบดิน - หน้ากากอนามัย รวม 5 รายการ พด.551/61 ศศพ. โดยวิธีเฉพาะเจาะจง
# 7 ส.ค. 61
# ---------------
# โรงพยาบาลบางแก้ว
# 4,152
# ซื้อหน้ากากอนามัย  จำนวน 50 กล่อง  เข็มฉีดยา ขนาด 20 G X 1นิ้ว  จำนวน 20 กล่องเข็มฉีดยา ขนาด 26G X 1 นิ้ว  จำนวน 20 กล่อง โดยวิธีเฉพาะเจาะจง
# 6 ก.ย. 61
# ---------------
# โรงพยาบาลบางแก้ว
# 4,000
# ซื้อเข็มฉีดยา 22 G X 1นิ้ว จำนวน 20 กล่อง, หน้ากากอนามัย จำนวน 80 กล่อง โดยวิธีเฉพาะเจาะจง
# 7 ธ.ค. 60
# ---------------
# โรงพยาบาลเจ้าพระยายมราช
# 3,300
# ซื้อ61-400885	Mask หน้ากากอนามัยปิดปากและจมูก 3 ชั้น .. สำหรับเด็ก โดยวิธีเฉพาะเจาะจง
# 27 ส.ค. 61
# ---------------
# องค์การบริหารส่วนตำบลท่าเสม็ด
# 1,320
# ซื้อจัดซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ (หน้ากากอนามัย) เพื่อใช้งานในการจัดเก็บขยะมูลฝอยในพื้นที่ตำบลท่าเสม็ด โดยวิธีเฉพาะเจาะจง
# 14 ก.ย. 61
# ---------------
# กรมส่งเสริมการปกครองท้องถิ่น
# 1,104
# ซื้อวัสดุวิทยาศาสตร์หรือการแพทย์ หน้ากากอนามัย จำนวน 24 กล่อง โดยวิธีเฉพาะเจาะจง
# 7 ก.ย. 61
# ---------------
# องค์การบริหารส่วนตำบลวังก์พง
# 1,000
# ซื้อจัดซื้อวัสดุทางการแพทย์ (ถุงมือแพทย์และหน้ากากอนามัย)   ตามโครงการควบคุมป้องกันโรคพิษสุนัขบ้าตำบลวังก์พง ประจำปี  ๒๕๖๑ โดยวิธีเฉพาะเจาะจง
# 9 มี.ค. 61
# ---------------
# ***************************************************
# ค้นหาคำว่า: หน้ากากอนามัย งบประมาณทั้งหมด: 4,255,841 บาท
# ***************************************************
